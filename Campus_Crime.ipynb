# %%
import pandas as pd

# %%
import matplotlib.pyplot
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-864e826dab68> in <module>()
# ----> 1 import matplotlib.pyplot
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
# data = pd.read_csv('campus_crime.csv')

# %% [markdown]
# data = pd.read_csv('campus_crime.csv')

# %%
data[:1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-38828d5a123f> in <module>()
# ----> 1 data[:1]
#
# NameError: name 'data' is not defined

# %%
data = pd.read_csv('campus_crime.csv')

# %%
data[:1]
# Out:
#                  instname  total_enr  murder  manslaughter  forcible  \
# 0  American River College      95250       0             0         1
#
#    nonforce  robbery  agg_aslt  burglary  vehicle  arson
# 0         2        3         2         6        8      0

# %%
data.sort('murder', ascending=False)[:20]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-677ef63b0522> in <module>()
# ----> 1 data.sort('murder', ascending=False)[:20]
#
# /usr/local/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4382             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4383                 return self[name]
# -> 4384             return object.__getattribute__(self, name)
#    4385
#    4386     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'sort'

# %%
data.sort('murder', ascending=False)[:10]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-054e9929f76c> in <module>()
# ----> 1 data.sort('murder', ascending=False)[:10]
#
# /usr/local/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4382             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4383                 return self[name]
# -> 4384             return object.__getattribute__(self, name)
#    4385
#    4386     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'sort'

# %%
data.sort_murder
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-2197de09141e> in <module>()
# ----> 1 data.sort_murder
#
# /usr/local/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4382             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4383                 return self[name]
# -> 4384             return object.__getattribute__(self, name)
#    4385
#    4386     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'sort_murder'

# %%
data.sort('murder')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-e66030b97900> in <module>()
# ----> 1 data.sort('murder')
#
# /usr/local/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4382             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4383                 return self[name]
# -> 4384             return object.__getattribute__(self, name)
#    4385
#    4386     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'sort'

# %%
data[data.instname == 'University of Missouri-Columbia']
# Out:
#                             instname  total_enr  murder  manslaughter  \
# 195  University of Missouri-Columbia      33762       0             0
#
#      forcible  nonforce  robbery  agg_aslt  burglary  vehicle  arson
# 195        11         0        1         8        10        1      1

# %%
data.sort('murder', ascending=False)[:10]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-054e9929f76c> in <module>()
# ----> 1 data.sort('murder', ascending=False)[:10]
#
# /usr/local/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4382             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4383                 return self[name]
# -> 4384             return object.__getattribute__(self, name)
#    4385
#    4386     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'sort'

# %%
dataframe.sort('murder', ascending=False)[:10]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-8db3a14994dc> in <module>()
# ----> 1 dataframe.sort('murder', ascending=False)[:10]
#
# NameError: name 'dataframe' is not defined

# %%
data.sort_values(by 'murder', ascending=False)
# Out:
#   File "<ipython-input-15-9e6a9d2bb875>", line 1
#     data.sort_values(by 'murder', ascending=False)
#                                ^
# SyntaxError: invalid syntax

# %%
data.sort_values(by 'murder')
# Out:
#   File "<ipython-input-16-7f35a256a970>", line 1
#     data.sort_values(by 'murder')
#                                ^
# SyntaxError: invalid syntax

# %%
data.sort_values(['murder'], ascending=False)
# Out:
#                                               instname  total_enr  murder  \
# 133                          San Jose State University      60472       2
# 164                              University of Arizona      39236       1
# 219  Virginia Polytechnic Institute and State Unive...     371232       1
# 183                  University of Illinois at Chicago      84273       1
# 0                               American River College      95250       0
# 155                 The University of Texas at El Paso      22640       0
# 145                    Tarrant County College District     300372       0
# 146                                  Temple University     294840       0
# 147             Texas A & M University-College Station     100460       0
# 148                  Texas State University-San Marcos      68174       0
# 149                              Texas Tech University     226289       0
# 150          The Community College of Baltimore County     157626       0
# ...

# %%
data.sort_values(['forcible'], ascending=False)[:10]
# Out:
#                                               instname  total_enr  murder  \
# 166                  University of California-Berkeley      72274       0
# 107                  Ohio State University-Main Campus      56867       0
# 167                     University of California-Davis      63464       0
# 213                    University of Wisconsin-Madison      41946       0
# 116          Pennsylvania State University-Main Campus      45628       0
# 65                                  Harvard University      54784       0
# 1                             Arizona State University     289016       0
# 56                        George Washington University     202080       0
# 91                           Michigan State University     191300       0
# 219  Virginia Polytechnic Institute and State Unive...     371232       1
#
#      manslaughter  forcible  nonforce  robbery  agg_aslt  burglary  vehicle  \
# 166             0        30         1        9         7        40       14
# ...

# %%
data.sort_values(['burglary'], ascending=False)[:10]
# Out:
#                                       instname  total_enr  murder  \
# 209                       University of Toledo      67830       0
# 169       University of California-Los Angeles      39271       0
# 206      University of South Carolina-Columbia      30721       0
# 116  Pennsylvania State University-Main Campus      45628       0
# 142                     Stony Brook University      23920       0
# 210                         University of Utah      31660       0
# 1                     Arizona State University     289016       0
# 69              Indiana University-Bloomington      42731       0
# 167             University of California-Davis      63464       0
# 91                   Michigan State University     191300       0
#
#      manslaughter  forcible  nonforce  robbery  agg_aslt  burglary  vehicle  \
# 209             0         2         0        1         4       118        0
# 169             0         8         0        2         4       118        7
# ...

# %%
data.sort_values(['vehicle'], ascending=False)[:10]
# Out:
#                                     instname  total_enr  murder  manslaughter  \
# 198     University of New Mexico-Main Campus      28977       0             0
# 130               San Diego State University      30541       0             0
# 189      University of Maryland-College Park      75262       0             0
# 90                        Miami Dade College     509888       0             0
# 173            University of Central Florida     935440       0             0
# 197           University of Nevada-Las Vegas      54728       0             0
# 112                  Oregon State University      24962       0             0
# 13   California State University-Los Angeles      21284       0             0
# 170       University of California-Riverside      20900       0             0
# 182                    University of Houston     119460       0             0
#
#      forcible  nonforce  robbery  agg_aslt  burglary  vehicle  arson
# ...

# %%
#Okay, it took me about 2 hours of googling and trying things to get pandas to install and work. I couldn't get Seaborn to load, and at some point I had to give up and get on with life, you know? So my analysis is based onlin on Pandas. I'm sorry.

# %%
data[data.instname == 'University of Missouri-Columbia']
# Out:
#                             instname  total_enr  murder  manslaughter  \
# 195  University of Missouri-Columbia      33762       0             0
#
#      forcible  nonforce  robbery  agg_aslt  burglary  vehicle  arson
# 195        11         0        1         8        10        1      1

# %%
data[data.instname == 'University of Missouri-Kansas City']
# Out:
# Empty DataFrame
# Columns: [instname, total_enr, murder, manslaughter, forcible, nonforce, robbery, agg_aslt, burglary, vehicle, arson]
# Index: []

# %%
data[data.instname == 'University of Missouri-Columbia', 'University of Georgia', 'University of Alabama', 'University of South Carolina']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-a6ce2b52ca2a> in <module>()
# ----> 1 data[data.instname == 'University of Missouri-Columbia', 'University of Georgia', 'University of Alabama', 'University of South Carolina']
#
# /usr/local/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2685             return self._getitem_multilevel(key)
#    2686         else:
# -> 2687             return self._getitem_column(key)
#    2688
#    2689     def _getitem_column(self, key):
#
# /usr/local/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2692         # get column
#    2693         if self.columns.is_unique:
# -> 2694             return self._get_item_cache(key)
#    2695
#    2696         # duplicate columns & possible reduce dimensionality
#
# ...

# %%
data[data.instname == 'University of Georgia']
# Out:
#                   instname  total_enr  murder  manslaughter  forcible  \
# 180  University of Georgia      34816       0             0         5
#
#      nonforce  robbery  agg_aslt  burglary  vehicle  arson
# 180         0        1         2        53        5      3

# %%
#Story idea 1: Compare MU in all of these areas with other SEC schools. I know enrollment would factor in, so you'd have to look at all of these as per capita rates, but it would still be interesting.

# %%
#Story idea 2: Look at rates of each of these crimes by region of the U.S. Western states like California, New Mexico, Arizona, etc. have a lot going on. How does that compare to other areas of the country? Which areas seem to be most violent, and for what charges? What's up with New Msico having the most vehicle issues? Especially for such a small campus.

# %%
data.sort_values(['manslaughter'], ascending=False)[:10]
# Out:
#                                       instname  total_enr  murder  \
# 51                    Florida State University      41087       0
# 0                       American River College      95250       0
# 157                Thomas Edison State College      20251       0
# 146                          Temple University     294840       0
# 147     Texas A & M University-College Station     100460       0
# 148          Texas State University-San Marcos      68174       0
# 149                      Texas Tech University     226289       0
# 150  The Community College of Baltimore County     157626       0
# 151                  The University of Alabama      63294       0
# 152                The University of Tennessee      90582       0
#
#      manslaughter  forcible  nonforce  robbery  agg_aslt  burglary  vehicle  \
# 51              1         2         0        8         8        67       10
# 0               0         1         2        3         2         6        8
# ...

# %%
data.sort_values(['robbery'], ascending=False)[:10]
# Out:
#                                               instname  total_enr  murder  \
# 71                   Instituto de Banca y Comercio Inc      20876       0
# 1                             Arizona State University     289016       0
# 173                      University of Central Florida     935440       0
# 86   Louisiana State University and Agricultural & ...      29718       0
# 204                         University of Pennsylvania     148992       0
# 166                  University of California-Berkeley      72274       0
# 51                            Florida State University      41087       0
# 107                  Ohio State University-Main Campus      56867       0
# 150          The Community College of Baltimore County     157626       0
# 200          University of North Carolina at Charlotte      25277       0
#
#      manslaughter  forcible  nonforce  robbery  agg_aslt  burglary  vehicle  \
# 71              0         0         0       19         1         4        0
# ...

# %%
data.sort_values(['arson'], ascending=False)[:10]
# Out:
#                                       instname  total_enr  murder  \
# 116  Pennsylvania State University-Main Campus      45628       0
# 1                     Arizona State University     289016       0
# 140              St John's University-New York     147469       0
# 43                 Eastern Michigan University     210771       0
# 52                         Fresno City College      40270       0
# 108                Ohio University-Main Campus      26201       0
# 107          Ohio State University-Main Campus      56867       0
# 166          University of California-Berkeley      72274       0
# 15      California State University-Sacramento      28016       0
# 133                  San Jose State University      60472       2
#
#      manslaughter  forcible  nonforce  robbery  agg_aslt  burglary  vehicle  \
# 116             0        24         0        2         6       112        1
# 1               0        17         1       11        27        90       17
# ...

# %%
datadata[["total_count""total_ ] = data["murder"] + data["manslaughter"] + data["forcible"]\
  + data["nonforce"] + data["robbery"] + data["agg_aslt"] + data["burglary"]\
  + data['vehicle'] + data["arson"]

data[:5]
# Out:
#   File "<ipython-input-28-dc2e5e541c14>", line 1
#     datadata[["total_count""total_ ] = data["murder"] + data["manslaughter"] + data["forcible"]  + data["nonforce"] + data["robbery"] + data["agg_aslt"] + data["burglary"]  + data['vehicle'] + data["arson"]
#                                                   ^
# SyntaxError: invalid syntax

# %%
data["total_count"] = data["murder"] + data["manslaughter"] + data["forcible"]\
  + data["nonforce"] + data["robbery"] + data["agg_aslt"] + data["burglary"]\
  + data['vehicle'] + data["arson"]

# %%
data[:5]
# Out:
#                             instname  total_enr  murder  manslaughter  \
# 0             American River College      95250       0             0
# 1           Arizona State University     289016       0             0
# 2                 Ashford University      74596       0             0
# 3                  Auburn University      25469       0             0
# 4  Austin Community College District    1082400       0             0
#
#    forcible  nonforce  robbery  agg_aslt  burglary  vehicle  arson  \
# 0         1         2        3         2         6        8      0
# 1        17         1       11        27        90       17     11
# 2         2         0        0         0         1        0      0
# 3         1         0        2         0        22        3      0
# 4         0         0        0         1         2        0      0
#
#    total_count
# 0           22
# 1          174
# 2            3
# 3           28
# 4            3

# %%
data
# Out:
#                                               instname  total_enr  murder  \
# 0                               American River College      95250       0
# 1                             Arizona State University     289016       0
# 2                                   Ashford University      74596       0
# 3                                    Auburn University      25469       0
# 4                    Austin Community College District    1082400       0
# 5                                Ball State University      44294       0
# 6                                    Boston University      64878       0
# 7                       Brigham Young University-Provo     170505       0
# 8                                      Broward College     379782       0
# 9       California State Polytechnic University-Pomona      21107       0
# 10                  California State University-Fresno      21981       0
# 11               California State University-Fullerton     144624       0
# ...

# %%
data.sort_values(['total count'], ascending=False)[:10]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-32-38f3d69eddd1> in <module>()
# ----> 1 data.sort_values(['total count'], ascending=False)[:10]
#
# /usr/local/lib/python3.6/site-packages/pandas/core/frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position)
#    4412             by = by[0]
#    4413             k = self._get_label_or_level_values(by, axis=axis,
# -> 4414                                                 stacklevel=stacklevel)
#    4415
#    4416             if isinstance(ascending, (tuple, list)):
#
# /usr/local/lib/python3.6/site-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis, stacklevel)
#    1378             values = self.axes[axis].get_level_values(key)._values
#    1379         else:
# -> 1380             raise KeyError(key)
#    1381
#    1382         # Check for duplicates
#
# ...

# %%
#Story idea 3: Look at the universities that apparently don't have any crime (looking at you, Walden and Capella, wherever those are) and find out why/if that's true.

# %%
#Story idea 4: Look at the univerities that have the most total crime (Arizona, South Carolina, Toledo) and see what the characteristics are of each city, what the similarities and contributing factors could be, etc.
